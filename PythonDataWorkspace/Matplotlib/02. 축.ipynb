# %% [markdown]
# # 2. 축

# %%
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['font.family'] = 'AppleGothic' 
matplotlib.rcParams['font.family'] = 'Malgun Gothic'
matplotlib.rcParams['font.size'] = 15
matplotlib.rcParams['axes.unicode_minus'] = False # 한글 폰트 사용 시, 마이너스 글자가 깨지는 현상 해결

# %%
x = [1,2,3]
y = [2,4,8]

# %%
plt.plot(x,y)
# plt.title('꺾은선 그래프', fontdict={'family': 'HYGungo-Bold', 'size':20}) # 개별 폰트 설정

# %%
plt.plot(x,y)
plt.xlabel('x축')
plt.ylabel('y축')
# Out:
# Text(0, 0.5, 'y축')

# %%
plt.plot(x,y)
plt.xlabel('x축', color='r')
plt.ylabel('y축', color='#00aa00')
# Out:
# Text(0, 0.5, 'y축')

# %%
plt.plot(x,y)
plt.xlabel('x축', color='r', loc='right') # left, center, ritgh
plt.ylabel('y축', color='#00aa00', loc='top') # top, center, bottom
# Out:
# Text(0, 1, 'y축')

# %%
# tick : 그래프의 축에 간격을 구분하기 위해 표시하는 눈금
plt.plot(x,y)
plt.xticks([1,2,3])
plt.yticks([3,6,9,12])
plt.show()
